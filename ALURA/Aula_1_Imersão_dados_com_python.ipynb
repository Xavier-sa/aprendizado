# %% [markdown]
# <a href="https://colab.research.google.com/github/Xavier-sa/aprendizado/blob/python%2Falura/ALURA/Aula_1_Imers%C3%A3o_dados_com_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")


df.head(10)
# df.info()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['work_year'].plot(kind='hist', bins=20, title='work_year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df.min()
# Out:
# work_year                   2020.0
# experience_level                EN
# employment_type                 CT
# job_title             AI Architect
# salary                       14000
# salary_currency                AUD
# salary_in_usd                15000
# employee_residence              AD
# remote_ratio                     0
# company_location                AD
# company_size                     L
# dtype: object

# %%
df.media()

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("Linhas:", linhas)
print("Colunas:", colunas)
# Out:
# Linhas: 133349
# Colunas: 11

# %%
df.columns
# Out:
# Index(['ano_trabalhado', 'nivel_experiencia', 'tipo_emprego', 'cargo',
#        'salario', 'moeda_salario', 'salario_em_usd', 'residencia_empregado',
#        'proporcao_remoto', 'localizacao_empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
# Traduzindo as colunas igual dicionario abaixo

translated_columns = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

df.rename(columns=translated_columns, inplace=True)

print("Translated columns:")
print(df.columns)
# Out:
# Translated columns:
# Index(['ano_trabalhado', 'nivel_experiencia', 'tipo_emprego', 'cargo',
#        'salario', 'moeda_salario', 'salario_em_usd', 'residencia_empregado',
#        'proporcao_remoto', 'localizacao_empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df['nivel_experiencia'].value_counts()

nivel_experiencia = {
    'EN': 'Junior',
    'MI': 'Pleno',
    'SE': 'Senior',
    'EX': 'Executivo'
}

df['nivel_experiencia'] = df['nivel_experiencia'].replace(nivel_experiencia)
df['nivel_experiencia'].value_counts()
# Out:
# nivel_experiencia
# Senior       77241
# Pleno        40465
# Junior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
df['proporcao_remoto'].value_counts()
df['cargo'].value_counts()
# Out:
# cargo
# Data Scientist                     17314
# Software Engineer                  15007
# Data Engineer                      14868
# Data Analyst                       12381
# Engineer                            9456
#                                    ...
# Quantitative Research Analyst          1
# Data Science Tech Lead                 1
# Staff Machine Learning Engineer        1
# Principal Data Architect               1
# Cloud Data Architect                   1
# Name: count, Length: 390, dtype: int64

# %%
df.head()
# Out:
#    ano_trabalhado nivel_experiencia tipo_emprego               cargo  salario  \
# 0          2025.0            Senior           FT  Solutions Engineer   214000
# 1          2025.0            Senior           FT  Solutions Engineer   136000
# 2          2025.0             Pleno           FT       Data Engineer   158800
# 3          2025.0             Pleno           FT       Data Engineer   139200
# 4          2025.0            Junior           FT       Data Engineer    90000
#
#   moeda_salario  salario_em_usd residencia_empregado  proporcao_remoto  \
# 0           USD          214000                   US               100
# 1           USD          136000                   US               100
# 2           USD          158800                   AU                 0
# 3           USD          139200                   AU                 0
# 4           USD           90000                   US                 0
#
#   localizacao_empresa tamanho_empresa
# ...

# %%
df['proporcao_remoto'].value_counts()
# Out:
# proporcao_remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
print(f"Fim AULA 1")
# Out:
# Fim AULA 1

# %% [markdown]
# ***----------------------------------**

# %%
#AULA 2

# %%
df.head()
# Out:
#    ano_trabalhado nivel_experiencia tipo_emprego               cargo  salario  \
# 0          2025.0            Senior           FT  Solutions Engineer   214000
# 1          2025.0            Senior           FT  Solutions Engineer   136000
# 2          2025.0             Pleno           FT       Data Engineer   158800
# 3          2025.0             Pleno           FT       Data Engineer   139200
# 4          2025.0            Junior           FT       Data Engineer    90000
#
#   moeda_salario  salario_em_usd residencia_empregado  proporcao_remoto  \
# 0           USD          214000                   US               100
# 1           USD          136000                   US               100
# 2           USD          158800                   AU                 0
# 3           USD          139200                   AU                 0
# 4           USD           90000                   US                 0
#
#   localizacao_empresa tamanho_empresa
# ...

# %%
df.isnull().sum() # campos nao tem a variavel preenchida
# Out:
# ano_trabalhado          10
# nivel_experiencia        0
# tipo_emprego             0
# cargo                    0
# salario                  0
# moeda_salario            0
# salario_em_usd           0
# residencia_empregado     0
# proporcao_remoto         0
# localizacao_empresa      0
# tamanho_empresa          0
# dtype: int64

# %%
df['ano_trabalhado'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
 df[df.isnull().any(axis=1)]   #vai trazer tudo que for null
# Out:
#         ano_trabalhado nivel_experiencia tipo_emprego  \
# 5588               NaN            Senior           FT
# 59692              NaN             Pleno           FT
# 59710              NaN            Junior           FT
# 59759              NaN            Senior           FT
# 59789              NaN            Senior           FT
# 131000             NaN            Senior           FT
# 131006             NaN            Senior           FT
# 133054             NaN            Junior           FT
# 133281             NaN             Pleno           FT
# 133317             NaN             Pleno           FT
#
#                             cargo  salario moeda_salario  salario_em_usd  \
# 5588              Product Manager   184500           USD          184500
# 59692                    Engineer   110000           USD          110000
# 59710              Data Scientist   208800           USD          208800
# 59759           Software Engineer   135000           USD          135000
# ...

# %%
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00          4000.00
# 1    Bruno       NaN       36333.33         36333.33
# 2   Carlos    5000.0        5000.00          5000.00
# 3  Daniele       NaN       36333.33         36333.33
# 4      Val  100000.0      100000.00        100000.00

# %%
import numpy as np

# Criação de um dataframe de teste para usar de exemplo
df_salarios = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    'salario': [4000, np.nan, 5000, np.nan, 100000]
})

# calcula a média salarial e substitui os nulos pela média e arrededonda os valores
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

'''Calcula mediana e substitui os nulos pela mediana
'''

df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
df_cidades = pd.DataFrame({
    'nome': ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    'cidade': ["São Paulo", np.nan, "Curitiba", np.nan, "Belém"]
})

df_cidades['cidade_preenchida'] = df_cidades["cidade"].fillna("Não informado")
display(df_cidades)
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %%
df_limpo = df.dropna()

# %%
df.isnull().sum()
# Out:
# ano_trabalhado          10
# nivel_experiencia        0
# tipo_emprego             0
# cargo                    0
# salario                  0
# moeda_salario            0
# salario_em_usd           0
# residencia_empregado     0
# proporcao_remoto         0
# localizacao_empresa      0
# tamanho_empresa          0
# dtype: int64

# %%
df_limpo.isnull().sum()
# Out:
# ano_trabalhado          0
# nivel_experiencia       0
# tipo_emprego            0
# cargo                   0
# salario                 0
# moeda_salario           0
# salario_em_usd          0
# residencia_empregado    0
# proporcao_remoto        0
# localizacao_empresa     0
# tamanho_empresa         0
# dtype: int64

# %%
df_limpo.head()
# Out:
#    ano_trabalhado nivel_experiencia tipo_emprego               cargo  salario  \
# 0          2025.0            Senior           FT  Solutions Engineer   214000
# 1          2025.0            Senior           FT  Solutions Engineer   136000
# 2          2025.0             Pleno           FT       Data Engineer   158800
# 3          2025.0             Pleno           FT       Data Engineer   139200
# 4          2025.0            Junior           FT       Data Engineer    90000
#
#   moeda_salario  salario_em_usd residencia_empregado  proporcao_remoto  \
# 0           USD          214000                   US               100
# 1           USD          136000                   US               100
# 2           USD          158800                   AU                 0
# 3           USD          139200                   AU                 0
# 4           USD           90000                   US                 0
#
#   localizacao_empresa tamanho_empresa
# ...

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ano_trabalhado        133339 non-null  float64
#  1   nivel_experiencia     133339 non-null  object
#  2   tipo_emprego          133339 non-null  object
#  3   cargo                 133339 non-null  object
#  4   salario               133339 non-null  int64
#  5   moeda_salario         133339 non-null  object
#  6   salario_em_usd        133339 non-null  int64
#  7   residencia_empregado  133339 non-null  object
#  8   proporcao_remoto      133339 non-null  int64
#  9   localizacao_empresa   133339 non-null  object
#  10  tamanho_empresa       133339 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 12.2+ MB

# %%
df_limpo = df_limpo.assign(ano_trabalhado =df_limpo['ano_trabalhado'].astype('int64'))

# %%
df_limpo.head()
# Out:
#    ano_trabalhado nivel_experiencia tipo_emprego               cargo  salario  \
# 0            2025            Senior           FT  Solutions Engineer   214000
# 1            2025            Senior           FT  Solutions Engineer   136000
# 2            2025             Pleno           FT       Data Engineer   158800
# 3            2025             Pleno           FT       Data Engineer   139200
# 4            2025            Junior           FT       Data Engineer    90000
#
#   moeda_salario  salario_em_usd residencia_empregado  proporcao_remoto  \
# 0           USD          214000                   US               100
# 1           USD          136000                   US               100
# 2           USD          158800                   AU                 0
# 3           USD          139200                   AU                 0
# 4           USD           90000                   US                 0
#
#   localizacao_empresa tamanho_empresa
# ...
